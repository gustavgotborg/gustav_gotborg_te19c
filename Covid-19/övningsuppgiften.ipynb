# %%
import pandas as pd 
import matplotlib.pyplot as plt

dd = pd.read_csv("National_Daily_Deaths.csv")

dd_death = dd["Sweden_Daily_Deaths"]

dd_date = dd["Date"]


plt.plot(dd_date,dd_death)
plt.show()
